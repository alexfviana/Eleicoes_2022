# %% [markdown]
# # Eleições Presidenciais - Brasil 2022

# %% [markdown]
# ##  Verificação das anomalias apresentadas em live realizada na Argentina em 05/11/2011 por meio das informações publicadas do 2º Turno pelo Portal de Dados Abertos do TSE.

# %%
# Importando s bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import geobr
import matplotlib.ticker as ticker
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# As informaçòes deste notebook podem ser replicadas para qualquer UF, sendo necessária apenas a substituição do arquivo .csv da célula abaixo. Os arquivos de todas as UF de resultados de boletins das urnas foram disponibilizadas pelo Portal de Dados Abertos do TSE - https://dadosabertos.tse.jus.br/dataset/resultados-2022-boletim-de-urna

# %%
arquivo = 'bweb_2t_AL_311020221535.csv'
data = pd.read_csv(arquivo, sep=';', encoding='Latin 1', low_memory=False)

# %%
# Filtrando apenas os dados das eleições presidenciais
df = data[data['DS_CARGO_PERGUNTA'] == 'Presidente'].reset_index(drop=True)

# %%
# Visualização do dataset
df.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 1  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 2  31/10/2022   15:36:48         2022                0  Eleição Ordinária
#
#    CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO                  DS_ELEICAO  \
# 0        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 1        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 2        407  30/10/2022         2         545  Eleição Geral Federal 2022
#
#    ... CD_FLASHCARD_URNA_EFETIVADA  DT_CARGA_URNA_EFETIVADA  \
# 0  ...                    587B7DAA      25/09/2022 08:05:00
# 1  ...                    587B7DAA      25/09/2022 08:05:00
# 2  ...                    587B7DAA      25/09/2022 08:05:00
#
#   DS_CARGO_PERGUNTA_SECAO  DS_AGREGADAS          DT_ABERTURA  \
# 0                   1 - 1             2  30/10/2022 08:00:01
# 1                   1 - 1             2  30/10/2022 08:00:01
# 2                   1 - 1             2  30/10/2022 08:00:01
#
#        DT_ENCERRAMENTO  QT_ELEITORES_BIOMETRIA_NH        DT_EMISSAO_BU  \
# 0  30/10/2022 17:01:12                         19  30/10/2022 17:03:53
# 1  30/10/2022 17:01:12                         19  30/10/2022 17:03:53
# 2  30/10/2022 17:01:12                         19  30/10/2022 17:03:53
#
#    NR_JUNTA_APURADORA NR_TURMA_APURADORA
# 0                  -1                 -1
# 1                  -1                 -1
# 2                  -1                 -1
#
# [3 rows x 45 columns]

# %%
# Colunas/informações disponíveis no dataset
df.columns
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'CD_PLEITO', 'DT_PLEITO', 'NR_TURNO', 'CD_ELEICAO',
#        'DS_ELEICAO', 'SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_ZONA',
#        'NR_SECAO', 'NR_LOCAL_VOTACAO', 'CD_CARGO_PERGUNTA',
#        'DS_CARGO_PERGUNTA', 'NR_PARTIDO', 'SG_PARTIDO', 'NM_PARTIDO',
#        'DT_BU_RECEBIDO', 'QT_APTOS', 'QT_COMPARECIMENTO', 'QT_ABSTENCOES',
#        'CD_TIPO_URNA', 'DS_TIPO_URNA', 'CD_TIPO_VOTAVEL', 'DS_TIPO_VOTAVEL',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_URNA_EFETIVADA',
#        'CD_CARGA_1_URNA_EFETIVADA', 'CD_CARGA_2_URNA_EFETIVADA',
#        'CD_FLASHCARD_URNA_EFETIVADA', 'DT_CARGA_URNA_EFETIVADA',
#        'DS_CARGO_PERGUNTA_SECAO', 'DS_AGREGADAS', 'DT_ABERTURA',
#        'DT_ENCERRAMENTO', 'QT_ELEITORES_BIOMETRIA_NH', 'DT_EMISSAO_BU',
#        'NR_JUNTA_APURADORA', 'NR_TURMA_APURADORA'],
#       dtype='object')

# %% [markdown]
# A identificação do modelo da urna é realizado a partir da informação da coluna "NR_URNA_EFETIVADA" com o ID da urna, de acordo com as informação do TSE cada modelo de urna é referenciado pela sequência desse ID. Essa faixa sequencial é encontrada na página "Correspondência entre número interno e modelo da urna" https://dadosabertos.tse.jus.br/dataset/correspondencia-entre-numero-interno-e-modelo-da-urna-1

# %%
# Correspondência entre número interno e modelo da urna
df_model = pd.read_csv('modelourna_numerointerno.csv', sep=';', encoding='Latin 1')
df_model
# Out:
#    DS_MODELO_URNA  NR_FAIXA_INICIAL  NR_FAIXA_INICIAL.1
# 0            2009            999500             1220500
# 1            2010           1220501             1345500
# 2            2011           1368501             1370500
# 3            2011           1600000             1650000
# 4            2013           1650001             1701000
# 5            2015           1750000             1950000
# 6            2020           2000000             2250000

# %%
# Inserindo o modelo da urna ao DataFrame

# Função para identificação do modelo
def model(nr):
    for i in range(len(df_model)):
        if (nr >= df_model['NR_FAIXA_INICIAL'][i]) & (nr >= df_model['NR_FAIXA_INICIAL'][i]):
            mod = df_model['DS_MODELO_URNA'][i]
    return mod

# Inserção da coluna

lista = []
for i in range(len(df)):
    x = model(df['NR_URNA_EFETIVADA'][i])
    lista.append(x)

df['MODELO'] = lista

# %%
df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 1  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 2  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 3  31/10/2022   15:36:48         2022                0  Eleição Ordinária
# 4  31/10/2022   15:36:48         2022                0  Eleição Ordinária
#
#    CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO                  DS_ELEICAO  \
# 0        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 1        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 2        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 3        407  30/10/2022         2         545  Eleição Geral Federal 2022
# 4        407  30/10/2022         2         545  Eleição Geral Federal 2022
#
#    ... DT_CARGA_URNA_EFETIVADA  DS_CARGO_PERGUNTA_SECAO DS_AGREGADAS  \
# 0  ...     25/09/2022 08:05:00                    1 - 1            2
# 1  ...     25/09/2022 08:05:00                    1 - 1            2
# 2  ...     25/09/2022 08:05:00                    1 - 1            2
# 3  ...     25/09/2022 08:05:00                    1 - 1            2
# 4  ...     25/09/2022 08:09:00                    1 - 3            4
#
#            DT_ABERTURA      DT_ENCERRAMENTO  QT_ELEITORES_BIOMETRIA_NH  \
# 0  30/10/2022 08:00:01  30/10/2022 17:01:12                         19
# 1  30/10/2022 08:00:01  30/10/2022 17:01:12                         19
# 2  30/10/2022 08:00:01  30/10/2022 17:01:12                         19
# 3  30/10/2022 08:00:01  30/10/2022 17:01:12                         19
# 4  30/10/2022 08:00:01  30/10/2022 17:02:15                         18
#
#          DT_EMISSAO_BU NR_JUNTA_APURADORA  NR_TURMA_APURADORA MODELO
# 0  30/10/2022 17:03:53                 -1                  -1   2020
# 1  30/10/2022 17:03:53                 -1                  -1   2020
# 2  30/10/2022 17:03:53                 -1                  -1   2020
# 3  30/10/2022 17:03:53                 -1                  -1   2020
# 4  30/10/2022 17:03:54                 -1                  -1   2020
#
# [5 rows x 46 columns]

# %%
# Agrupamento das informações para consolidação dos resultados por urna
df_temp = df[['NR_URNA_EFETIVADA', 
              'NR_PARTIDO', 
              'QT_VOTOS']].groupby(['NR_URNA_EFETIVADA', 
                                    'NR_PARTIDO']).sum().reset_index()

# %%
# Visualização do dataset preliminar
# Votos nulos -> "NR_PARTIDO" = -1 
df_temp.head(6)
# Out:
#    NR_URNA_EFETIVADA  NR_PARTIDO  QT_VOTOS
# 0            1000241          -1        17
# 1            1000241          13       214
# 2            1000241          22        20
# 3            1000242          -1        16
# 4            1000242          13       152
# 5            1000242          22        58

# %%
# Consolidação dos resultados por direcionamento do voto (Nulo/Lula/Bolsonaro)

df_null = df_temp[df_temp['NR_PARTIDO'] == -1].reset_index(drop=True)
df_lula = df_temp[df_temp['NR_PARTIDO'] == 13].reset_index(drop=True)
df_bolsonaro = df_temp[df_temp['NR_PARTIDO'] == 22].reset_index(drop=True)

df_null.columns = ['NR_URNA_EFETIVADA', 'NR_PARTIDO', 'NULOS']
df_lula.columns = ['NR_URNA_EFETIVADA', 'NR_PARTIDO', 'LULA']
df_bolsonaro.columns = ['NR_URNA_EFETIVADA', 'NR_PARTIDO', 'BOLSO']

# %%
# Visualização da consolidação
df_null.head(3)
# Out:
#    NR_URNA_EFETIVADA  NR_PARTIDO  NULOS
# 0            1000241          -1     17
# 1            1000242          -1     16
# 2            1000530          -1     26

# %%
# Consolidação dos resultados por urna

colunas = ['NR_URNA_EFETIVADA', 'MODELO', 'NM_MUNICIPIO', 'QT_APTOS', 'QT_COMPARECIMENTO', 'QT_ABSTENCOES']
df1 = df[colunas].drop_duplicates().reset_index(drop=True)

# Inserção do quantitativo dos votos as dataframe
df1 = df1.merge(df_lula[['NR_URNA_EFETIVADA', 'LULA']], how='left', on='NR_URNA_EFETIVADA')
df1 = df1.merge(df_bolsonaro[['NR_URNA_EFETIVADA', 'BOLSO']], how='left', on='NR_URNA_EFETIVADA')
df1 = df1.merge(df_null[['NR_URNA_EFETIVADA', 'NULOS']], how='left', on='NR_URNA_EFETIVADA')

# Inserção dos cálculos percentuais
df1['%_LULA'] = round(100 * df1['LULA'] / df1['QT_COMPARECIMENTO'], 1)
df1['%_BOLSO'] = round(100 * df1['BOLSO'] / df1['QT_COMPARECIMENTO'], 1)
df1['%_NULOS'] = round(100 * df1['NULOS'] / df1['QT_COMPARECIMENTO'], 1)

# %%
# Visualização do dataframe
df1.head()
# Out:
#    NR_URNA_EFETIVADA  MODELO NM_MUNICIPIO  QT_APTOS  QT_COMPARECIMENTO  \
# 0            2071468    2020       MACEIÓ       336                265
# 1            2038339    2020       MACEIÓ       341                296
# 2            2072024    2020       MACEIÓ       336                278
# 3            2069479    2020       MACEIÓ       336                277
# 4            2074297    2020       MACEIÓ       341                280
#
#    QT_ABSTENCOES  LULA  BOLSO  NULOS  %_LULA  %_BOLSO  %_NULOS
# 0             71    99    148   18.0    37.4     55.8      6.8
# 1             45   116    154   26.0    39.2     52.0      8.8
# 2             58   115    144   19.0    41.4     51.8      6.8
# 3             59   118    142   17.0    42.6     51.3      6.1
# 4             61   106    160   14.0    37.9     57.1      5.0

# %%
# Síntese do dataframe
ab = round(100 * df1['QT_ABSTENCOES'].sum() / df1['QT_APTOS'].sum(), 2)
pt = round(100 * df1['LULA'].sum() / df1['QT_COMPARECIMENTO'].sum(), 2)
pl = round(100 * df1['BOLSO'].sum() / df1['QT_COMPARECIMENTO'].sum(), 2)
nu = round(100 * df1['NULOS'].sum() / df1['QT_COMPARECIMENTO'].sum(), 2)
print('Lula:', pt, '% dos votos')
print('Bolsonaro:', pl, '% dos votos')
print('Nulos:', nu, '% dos votos')
print('Abstenções:',ab, '% dos eleitores')
# Out:
# Lula: 54.72 % dos votos
# Bolsonaro: 38.53 % dos votos
# Nulos: 6.74 % dos votos
# Abstenções: 23.25 % dos eleitores

# %%
# Verificação do número de eleitores por município
df_eleitores = df1[['NM_MUNICIPIO', 
                    'QT_APTOS']].groupby('NM_MUNICIPIO').sum().sort_values('QT_APTOS', 
                                                                           ascending=False).reset_index()
df_eleitores.head(10)
# Out:
#             NM_MUNICIPIO  QT_APTOS
# 0                 MACEIÓ    629130
# 1              ARAPIRACA    150976
# 2              RIO LARGO     62222
# 3    PALMEIRA DOS ÍNDIOS     52597
# 4     UNIÃO DOS PALMARES     46244
# 5  SÃO MIGUEL DOS CAMPOS     42474
# 6                 PENEDO     42055
# 7       MARECHAL DEODORO     40919
# 8               CORURIPE     40155
# 9        DELMIRO GOUVEIA     39011

# %%
# Listando as cidades em grupos com menos de 100k e 50k eleitores
lista_100k = list(df_eleitores[df_eleitores['QT_APTOS'] <= 100000]['NM_MUNICIPIO'])
lista_50k = list(df_eleitores[df_eleitores['QT_APTOS'] <= 50000]['NM_MUNICIPIO'])
lista_50k[:10]
# Out:
# ['UNIÃO DOS PALMARES',
#  'SÃO MIGUEL DOS CAMPOS',
#  'PENEDO',
#  'MARECHAL DEODORO',
#  'CORURIPE',
#  'DELMIRO GOUVEIA',
#  'SANTANA DO IPANEMA',
#  'ATALAIA',
#  'TEOTÔNIO VILELA',
#  'GIRAU DO PONCIANO']

# %%
# Dataframe com teto de eleitores por município
df_100k = df1[df1['NM_MUNICIPIO'].isin(lista_100k)]
df_50k = df1[df1['NM_MUNICIPIO'].isin(lista_50k)]

# %%
df_50k.head(3)
# Out:
#       NR_URNA_EFETIVADA  MODELO  NM_MUNICIPIO  QT_APTOS  QT_COMPARECIMENTO  \
# 1067            1672632    2013  MAR VERMELHO       370                300
# 1068            1672605    2013  MAR VERMELHO       367                287
# 1069            1673250    2013  MAR VERMELHO       365                278
#
#       QT_ABSTENCOES  LULA  BOLSO  NULOS  %_LULA  %_BOLSO  %_NULOS
# 1067             70   190     96   14.0    63.3     32.0      4.7
# 1068             80   194     73   20.0    67.6     25.4      7.0
# 1069             87   192     71   15.0    69.1     25.5      5.4

# %%
x = df_100k['BOLSO']
y = df_100k['LULA']

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, y, alpha=0.2, edgecolors='none')
ax.set_xlabel('Votos Bolsonaro')
ax.set_ylabel('Votos Lula')
ax.set_title('Resultados das urnas abaixo de 100k eleitores')
ax.set_xlim(-5,)
ax.set_ylim(-5,)

ax.grid(True)

plt.show()

# %%
# Distribuição dos modelos de urnas
mod = df_100k['MODELO'].value_counts().reset_index()
mod['%'] = round(100 * mod['MODELO'] / mod['MODELO'].sum(), 2)
mod.columns = ['ANO', 'QTD', '%']
mod
# Out:
#     ANO   QTD      %
# 0  2009  1204  26.11
# 1  2010  1191  25.83
# 2  2015   966  20.95
# 3  2020   783  16.98
# 4  2013   467  10.13

# %%
# Dividindo os dataframes entre as urnas de fabricação 2020 e as demais
df_100k_2020 = df_100k[df_100k['MODELO'] == 2020]
df_100k_outras = df_100k[df_100k['MODELO'] != 2020]

df_50k_2020 = df_50k[df_50k['MODELO'] == 2020]
df_50k_outras = df_50k[df_50k['MODELO'] != 2020]

# %% [markdown]
# ## Resultados para municípios até 100.000 eleitores

# %%
# Gráfico para o grupo de municípios ate 100k eleitores
# Urnas 2020
x1 = df_100k_2020['BOLSO']
y1 = df_100k_2020['LULA']
# Urnas de outros modelos
x2 = df_100k_outras['BOLSO']
y2 = df_100k_outras['LULA']

# Urnas 2020
x3 = df_100k_2020['%_BOLSO']
y3 = df_100k_2020['%_LULA']
# Urnas de outros modelos
x4 = df_100k_outras['%_BOLSO']
y4 = df_100k_outras['%_LULA']


fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(8,8))
fig.suptitle('Resultados das Urnas do Estado para cidades com até 100.000 eleitores', fontsize=14, fontweight='bold')

ax1.scatter(x1, y1, alpha=0.1, edgecolors='none')
ax1.set_xlabel('Votos Bolsonaro')
ax1.set_ylabel('Votos Lula')
ax1.set_title('Mod. 2020')
ax1.set_xlim(-5, 300)
ax1.set_ylim(-5, 300)
ax1.grid(True)

ax2.scatter(x2, y2, alpha=0.1, edgecolors='none')
ax2.set_xlabel('Votos Bolsonaro')
ax2.set_ylabel('Votos Lula')
ax2.set_title('Outros Modelos')
ax2.set_xlim(-5, 300)
ax2.set_ylim(-5, 300)
ax2.grid(True)

ax3.scatter(x3, y3, alpha=0.1, edgecolors='none')
ax3.set_xlabel('% Bolsonaro')
ax3.set_ylabel('% Lula')
ax3.set_xlim(-2, 100)
ax3.set_ylim(-2, 100)
ax3.grid(True)

ax4.scatter(x4, y4, alpha=0.1, edgecolors='none')
ax4.set_xlabel('% Bolsonaro')
ax4.set_ylabel('% Lula')
ax4.set_xlim(-2, 100)
ax4.set_ylim(-2, 100)
ax4.grid(True)

plt.show()

# %%
# Gráfico de distribuição dos votos por modelo de urna

curva_2020 = round(df_100k_2020['%_LULA'], 0)
curva_outras = round(df_100k_outras['%_LULA'], 0)

# plot:
fig, ax = plt.subplots()
fig.suptitle('Resultados das Urnas do Estado para cidades com até 100.000 eleitores', fontsize=14, fontweight='bold')

ax.hist(curva_2020, bins=15, linewidth=0.5, edgecolor="white", label='Modelo 2020', density=True, alpha=0.8)
ax.hist(curva_outras, bins=15, linewidth=0.5, edgecolor="white", label='Outros Modelos', color='red', density=True, alpha=0.8)

ax.set_xlabel('% Lula')
ax.set_ylabel('Densidade')
ax.set_title('Distribuição dos votos por modelo de urna')
ax.legend(loc='upper left')

plt.show()

# %%
# Síntese do dataframe

ab = round(100 * df_100k_2020['QT_ABSTENCOES'].sum() / df_100k_2020['QT_APTOS'].sum(), 2)
pt = round(100 * df_100k_2020['LULA'].sum() / df_100k_2020['QT_COMPARECIMENTO'].sum(), 2)
pl = round(100 * df_100k_2020['BOLSO'].sum() / df_100k_2020['QT_COMPARECIMENTO'].sum(), 2)
nu = round(100 * df_100k_2020['NULOS'].sum() / df_100k_2020['QT_COMPARECIMENTO'].sum(), 2)
print('Cidades até 100k habitantes - urnas modelo 2020')
print('Lula:', pt, '% dos votos')
print('Bolsonaro:', pl, '% dos votos')
print('Nulos:', nu, '% dos votos')
print('Abstenções:',ab, '% dos eleitores \n')

ab = round(100 * df_100k_outras['QT_ABSTENCOES'].sum() / df_100k_outras['QT_APTOS'].sum(), 2)
pt = round(100 * df_100k_outras['LULA'].sum() / df_100k_outras['QT_COMPARECIMENTO'].sum(), 2)
pl = round(100 * df_100k_outras['BOLSO'].sum() / df_100k_outras['QT_COMPARECIMENTO'].sum(), 2)
nu = round(100 * df_100k_outras['NULOS'].sum() / df_100k_outras['QT_COMPARECIMENTO'].sum(), 2)
print('Cidades até 100k habitantes - urnas de demais modelos')
print('Lula:', pt, '% dos votos')
print('Bolsonaro:', pl, '% dos votos')
print('Nulos:', nu, '% dos votos')
print('Abstenções:',ab, '% dos eleitores')
# Out:
# Cidades até 100k habitantes - urnas modelo 2020
# Lula: 49.31 % dos votos
# Bolsonaro: 43.86 % dos votos
# Nulos: 6.83 % dos votos
# Abstenções: 22.55 % dos eleitores
#
# Cidades até 100k habitantes - urnas de demais modelos
# Lula: 64.6 % dos votos
# Bolsonaro: 28.62 % dos votos
# Nulos: 6.78 % dos votos
# Abstenções: 26.34 % dos eleitores

# %% [markdown]
# ## Resultados para municípios até 50.000 eleitores

# %%
# Gráfico para o grupo de municípios ate 50k eleitores
# Urnas 2020
x1 = df_50k_2020['BOLSO']
y1 = df_50k_2020['LULA']
# Urnas de outros modelos
x2 = df_50k_outras['BOLSO']
y2 = df_50k_outras['LULA']

# Urnas 2020
x3 = df_50k_2020['%_BOLSO']
y3 = df_50k_2020['%_LULA']
# Urnas de outros modelos
x4 = df_50k_outras['%_BOLSO']
y4 = df_50k_outras['%_LULA']


fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(8,8))
fig.suptitle('Resultados das Urnas do Estado para cidades com até 50.000 eleitores', fontsize=14, fontweight='bold')

ax1.scatter(x1, y1, alpha=0.1, edgecolors='none')
ax1.set_xlabel('Votos Bolsonaro')
ax1.set_ylabel('Votos Lula')
ax1.set_title('Mod. 2020')
ax1.set_xlim(-5, 300)
ax1.set_ylim(-5, 300)
ax1.grid(True)

ax2.scatter(x2, y2, alpha=0.1, edgecolors='none')
ax2.set_xlabel('Votos Bolsonaro')
ax2.set_ylabel('Votos Lula')
ax2.set_title('Outros Modelos')
ax2.set_xlim(-5, 300)
ax2.set_ylim(-5, 300)
ax2.grid(True)

ax3.scatter(x3, y3, alpha=0.1, edgecolors='none')
ax3.set_xlabel('% Bolsonaro')
ax3.set_ylabel('% Lula')
ax3.set_xlim(-2, 100)
ax3.set_ylim(-2, 100)
ax3.grid(True)

ax4.scatter(x4, y4, alpha=0.1, edgecolors='none')
ax4.set_xlabel('% Bolsonaro')
ax4.set_ylabel('% Lula')
ax4.set_xlim(-2, 100)
ax4.set_ylim(-2, 100)
ax4.grid(True)

plt.show()

# %%
# Gráfico de distribuição dos votos por modelo de urna

curva_2020 = round(df_50k_2020['%_LULA'], 0)
curva_outras = round(df_50k_outras['%_LULA'], 0)

# plot:
fig, ax = plt.subplots()
fig.suptitle('Resultados das Urnas do Estado para cidades com até 50.000 eleitores', fontsize=14, fontweight='bold')

ax.hist(curva_2020, bins=15, linewidth=0.5, edgecolor="white", label='Modelo 2020', density=True, alpha=0.8)
ax.hist(curva_outras, bins=15, linewidth=0.5, edgecolor="white", label='Outros Modelos', color='red', density=True, alpha=0.8)

ax.set_xlabel('% Lula')
ax.set_ylabel('Densidade')
ax.set_title('Distribuição dos votos por modelo de urna')
ax.legend(loc='upper left')

plt.show()

# %%
# Síntese do dataframe

ab = round(100 * df_50k_2020['QT_ABSTENCOES'].sum() / df_50k_2020['QT_APTOS'].sum(), 2)
pt = round(100 * df_50k_2020['LULA'].sum() / df_50k_2020['QT_COMPARECIMENTO'].sum(), 2)
pl = round(100 * df_50k_2020['BOLSO'].sum() / df_50k_2020['QT_COMPARECIMENTO'].sum(), 2)
nu = round(100 * df_50k_2020['NULOS'].sum() / df_50k_2020['QT_COMPARECIMENTO'].sum(), 2)
print('Cidades até 50k habitantes - urnas modelo 2020')
print('Lula:', pt, '% dos votos')
print('Bolsonaro:', pl, '% dos votos')
print('Nulos:', nu, '% dos votos')
print('Abstenções:',ab, '% dos eleitores \n')

ab = round(100 * df_50k_outras['QT_ABSTENCOES'].sum() / df_50k_outras['QT_APTOS'].sum(), 2)
pt = round(100 * df_50k_outras['LULA'].sum() / df_50k_outras['QT_COMPARECIMENTO'].sum(), 2)
pl = round(100 * df_50k_outras['BOLSO'].sum() / df_50k_outras['QT_COMPARECIMENTO'].sum(), 2)
nu = round(100 * df_50k_outras['NULOS'].sum() / df_50k_outras['QT_COMPARECIMENTO'].sum(), 2)
print('Cidades até 50k habitantes - urnas de demais modelos')
print('Lula:', pt, '% dos votos')
print('Bolsonaro:', pl, '% dos votos')
print('Nulos:', nu, '% dos votos')
print('Abstenções:',ab, '% dos eleitores')
# Out:
# Cidades até 50k habitantes - urnas modelo 2020
# Lula: 49.57 % dos votos
# Bolsonaro: 43.57 % dos votos
# Nulos: 6.86 % dos votos
# Abstenções: 23.24 % dos eleitores
#
# Cidades até 50k habitantes - urnas de demais modelos
# Lula: 64.83 % dos votos
# Bolsonaro: 28.41 % dos votos
# Nulos: 6.77 % dos votos
# Abstenções: 26.45 % dos eleitores

# %% [markdown]
# ## Conclusão
#
# Percebe-se para ambos os grupos de municípios com 100.000 e 50.000 eleitores uma discrepância muito grande dos resultados mudando apenas a variável do modelo de urna utilizado, destacando-se a alta concentração de urnas que apresentaram um quantitativo de menos de 100 votos para Bolsonaro ou mais de 150 votos para Lula, bem como o quantitativo de urnas que apresentaram mais de 60% dos votos para Lula.
#
# Tendo em vista que as cidades são as mesmas e com grupo relativamente homogêneo de habitantes, tendo em vista que foram desconsideradas as capitais e maiores cidades do estado, com exceção do modelo da urna, todas as demais variáveis são iguais para ambos os grupos e a mudança de modelo não deveria apresentar variação na distribuição do resultado.
#
# Os resultados aqui apresentados validam a tese apresentada na live apresentada na Argentina por Fernando Cerimedo em 05/11/2022, bem como que as informações do Portal de dados abertos do TSE não sofreram alterações, tendo em vista que a base de dados deste notebook foi baixada no dia 06/11/2022, após boatos da alteração.

# %% [markdown]
# ## Estudos complementares

# %% [markdown]
# ### Localização dos municípios com urnas do modelo 2020

# %%
# Função para inclusão dos dados do GeoDataframe do Município

# Baixa o GeoDataFrame com os estados do Brasil e DF
br_mun = geobr.read_municipality()
br_mun.head()

#identificando a UF a partir do nome do arquivo
uf = arquivo[8:10]

# Reduzindo o GeoDaataFrame para o estado em análise
br_mun_uf = br_mun[br_mun['abbrev_state'] == uf].reset_index()

# Transformando a coluna de municípios para maiúscula para realizar o merge
br_mun_uf['name_muni'] = list(map(str.upper, br_mun_uf['name_muni']))

# Criando uma coluna identificando municípios com urnas do modelo 2020
mun_2020 = list(df_100k[df_100k['MODELO'] == 2020]['NM_MUNICIPIO'].unique())
capitais = ['FORTALEZA', 'MACEIÓ', 'SÃO LUÍS', 'JOÃO PESSOA', 'BELÉM', 'RECIFE', 'NATAL']

lista = []

for i in range(len(br_mun_uf)):
    if br_mun_uf['name_muni'][i] in capitais:
        x = 2
    else:
        if br_mun_uf['name_muni'][i] in mun_2020:
            x = 1
        else:
            x = 0
            
    lista.append(x)
    
br_mun_uf['mod_2020'] = lista


# Plotando o Mapa
data = br_mun_uf[['geometry', 'mod_2020']]

f, ax = plt.subplots()
f.set_size_inches(16, 16)
data.plot(ax=ax, # Axis de destino do gráfico
          column= 'mod_2020', # Coluna com os valores usados para colorir o mapa
          cmap='Blues', # Mapa de cores
          edgecolor='black', # Cor dos contornos
          linewidth=0.25) # Espessura dos contornos
# Out:
# <AxesSubplot:>

# %%
df_100k[['NM_MUNICIPIO', 'MODELO', 'QT_APTOS']].groupby(['NM_MUNICIPIO', 'MODELO']).sum()
# Out:
#                                QT_APTOS
# NM_MUNICIPIO           MODELO
# ANADIA                 2009        5404
#                        2010        7082
#                        2013         174
# ATALAIA                2020       31336
# BARRA DE SANTO ANTÔNIO 2009         661
# ...                                 ...
# VIÇOSA                 2015        9598
# ÁGUA BRANCA            2009        8407
#                        2010        5150
#                        2013        1186
#                        2015        1188
#
# [328 rows x 1 columns]

# %%
df_100k.head(3)
# Out:
#       NR_URNA_EFETIVADA  MODELO  NM_MUNICIPIO  QT_APTOS  QT_COMPARECIMENTO  \
# 1067            1672632    2013  MAR VERMELHO       370                300
# 1068            1672605    2013  MAR VERMELHO       367                287
# 1069            1673250    2013  MAR VERMELHO       365                278
#
#       QT_ABSTENCOES  LULA  BOLSO  NULOS  %_LULA  %_BOLSO  %_NULOS
# 1067             70   190     96   14.0    63.3     32.0      4.7
# 1068             80   194     73   20.0    67.6     25.4      7.0
# 1069             87   192     71   15.0    69.1     25.5      5.4

# %%
# Distribuição dos modelos de urnas nas cidades onde estão o modelo 2020

mun_2020 = df_100k[df_100k['MODELO'] == 2020]['NM_MUNICIPIO'].unique()

for i in range(len(mun_2020)):
    df= df_100k[df_100k['NM_MUNICIPIO'] == mun_2020[i]]
    n = df['QT_APTOS'].sum()
    print('Município: ', mun_2020[i],' - ', n, 'eleitores' )
    df = df['MODELO'].value_counts().reset_index()
    df['%'] = round(100 * df['MODELO'] / df['MODELO'].sum(), 2)
    df.columns = ['ANO', 'QTD', '%']
    print(df)
# Out:
# Município:  ATALAIA  -  31336 eleitores
#     ANO  QTD      %
# 0  2020  104  100.0
# Município:  CAPELA  -  12931 eleitores
#     ANO  QTD      %
# 0  2020   42  100.0
# Município:  PILAR  -  27254 eleitores
#     ANO  QTD      %
# 0  2020   77  100.0
# Município:  SANTA LUZIA DO NORTE  -  6090 eleitores
#     ANO  QTD      %
# 0  2020   16  100.0
# Município:  SATUBA  -  12489 eleitores
#     ANO  QTD      %
# 0  2020   35  100.0
# Município:  COQUEIRO SECO  -  5013 eleitores
#     ANO  QTD      %
# 0  2020   15  100.0
# Município:  RIO LARGO  -  62222 eleitores
#     ANO  QTD      %
# 0  2020  186  100.0
# Município:  ROTEIRO  -  5569 eleitores
#     ANO  QTD      %
# 0  2020   15  100.0
# Município:  SÃO MIGUEL DOS CAMPOS  -  42474 eleitores
#     ANO  QTD      %
# 0  2020  135  100.0
# Município:  JEQUIÁ DA PRAIA  -  7941 eleitores
#     ANO  QTD      %
# 0  2020   21  100.0
# Município:  MARECHAL DEODORO  -  40919 eleitores
#     ANO  QTD      %
# 0  2020  116  100.0
# Município:  BARRA DE SÃO MIGUEL  -  7322 eleitores
#     ANO  QTD      %
# 0  2020   21  100.0

# %%
# Distribuição dos modelos de urnas nas cidades onde estão o modelo 2020

mun_outros = df_100k[df_100k['MODELO'] != 2020]['NM_MUNICIPIO'].unique()

for i in range(len(mun_outros)):
    df= df_100k[df_100k['NM_MUNICIPIO'] == mun_outros[i]]
    n = df['QT_APTOS'].sum()
    print('Município: ', mun_outros[i],' - ', n, 'eleitores' )
    df = df['MODELO'].value_counts().reset_index()
    df['%'] = round(100 * df['MODELO'] / df['MODELO'].sum(), 2)
    df.columns = ['ANO', 'QTD', '%']
    print(df)
# Out:
# Município:  MAR VERMELHO  -  3536 eleitores
#     ANO  QTD     %
# 0  2013    6  60.0
# 1  2010    2  20.0
# 2  2009    1  10.0
# 3  2015    1  10.0
# Município:  VIÇOSA  -  20273 eleitores
#     ANO  QTD      %
# 0  2015   27  47.37
# 1  2009   13  22.81
# 2  2013   10  17.54
# 3  2010    7  12.28
# Município:  PINDOBA  -  2674 eleitores
#     ANO  QTD     %
# 0  2015    4  50.0
# 1  2009    2  25.0
# 2  2013    2  25.0
# Município:  CAJUEIRO  -  14547 eleitores
#     ANO  QTD      %
# 0  2010   16  38.10
# 1  2015   13  30.95
# 2  2013   10  23.81
# 3  2009    3   7.14
# Município:  CORURIPE  -  40155 eleitores
#     ANO  QTD      %
# 0  2009   57  48.72
# 1  2010   28  23.93
# 2  2013   17  14.53
# 3  2015   15  12.82
# Município:  FELIZ DESERTO  -  3523 eleitores
#     ANO  QTD     %
# 0  2009    4  40.0
# 1  2010    4  40.0
# 2  2013    1  10.0
# 3  2015    1  10.0
# Município:  BRANQUINHA  -  9105 eleitores
#     ANO  QTD      %
# 0  2009   14  53.85
# 1  2010   12  46.15
# Município:  MESSIAS  -  13597 eleitores
#     ANO  QTD      %
# 0  2010   20  57.14
# 1  2009   14  40.00
# 2  2013    1   2.86
# Município:  MURICI  -  20069 eleitores
#     ANO  QTD      %
# 0  2010   29  46.77
# 1  2009   22  35.48
# 2  2015    7  11.29
# 3  2013    4   6.45
# Município:  PALMEIRA DOS ÍNDIOS  -  52597 eleitores
#     ANO  QTD      %
# 0  2015   76  45.78
# 1  2009   48  28.92
# 2  2013   34  20.48
# 3  2010    8   4.82
# Município:  PALESTINA  -  4736 eleitores
#     ANO  QTD      %
# 0  2009    4  30.77
# 1  2010    3  23.08
# 2  2013    3  23.08
# 3  2015    3  23.08
# Município:  PÃO DE AÇÚCAR  -  18731 eleitores
#     ANO  QTD      %
# 0  2009   26  46.43
# 1  2010   21  37.50
# 2  2015    7  12.50
# 3  2013    2   3.57
# Município:  OLHO D'ÁGUA DAS FLORES  -  16000 eleitores
#     ANO  QTD      %
# 0  2010   23  50.00
# 1  2009   10  21.74
# 2  2013    7  15.22
# 3  2015    6  13.04
# Município:  PASSO DE CAMARAGIBE  -  11914 eleitores
#     ANO  QTD      %
# 0  2015   14  36.84
# 1  2010   13  34.21
# 2  2009    7  18.42
# 3  2013    4  10.53
# Município:  PORTO DE PEDRAS  -  7050 eleitores
#     ANO  QTD     %
# 0  2015   14  70.0
# 1  2010    6  30.0
# Município:  SÃO MIGUEL DOS MILAGRES  -  7365 eleitores
#     ANO  QTD     %
# 0  2015   16  80.0
# 1  2010    2  10.0
# 2  2009    1   5.0
# 3  2013    1   5.0
# Município:  MATRIZ DE CAMARAGIBE  -  18494 eleitores
#     ANO  QTD      %
# 0  2010   35  66.04
# 1  2015   15  28.30
# 2  2009    2   3.77
# 3  2013    1   1.89
# Município:  PENEDO  -  42055 eleitores
#     ANO  QTD      %
# 0  2009   48  35.82
# 1  2015   35  26.12
# 2  2010   29  21.64
# 3  2013   22  16.42
# Município:  PIAÇABUÇU  -  13554 eleitores
#     ANO  QTD      %
# 0  2009   13  29.55
# 1  2010   11  25.00
# 2  2015   11  25.00
# 3  2013    9  20.45
# Município:  JACUÍPE  -  5680 eleitores
#     ANO  QTD      %
# 0  2015   16  100.0
# Município:  JUNDIÁ  -  4470 eleitores
#     ANO  QTD      %
# 0  2010   10  76.92
# 1  2009    2  15.38
# 2  2013    1   7.69
# Município:  PORTO CALVO  -  20910 eleitores
#     ANO  QTD      %
# 0  2009   28  43.08
# 1  2010   23  35.38
# 2  2013    7  10.77
# 3  2015    7  10.77
# Município:  MARAGOGI  -  22512 eleitores
#     ANO  QTD      %
# 0  2015   23  36.51
# 1  2009   20  31.75
# 2  2010   19  30.16
# 3  2013    1   1.59
# Município:  JAPARATINGA  -  7166 eleitores
#     ANO  QTD      %
# 0  2010   10  47.62
# 1  2013    7  33.33
# 2  2009    2   9.52
# 3  2015    2   9.52
# Município:  IBATEGUARA  -  11370 eleitores
#     ANO  QTD      %
# 0  2010   18  58.06
# 1  2009   10  32.26
# 2  2015    2   6.45
# 3  2013    1   3.23
# Município:  SÃO JOSÉ DA LAJE  -  17350 eleitores
#     ANO  QTD      %
# 0  2009   38  79.17
# 1  2010   10  20.83
# Município:  COLÔNIA LEOPOLDINA  -  14848 eleitores
#     ANO  QTD      %
# 0  2010   23  44.23
# 1  2013   12  23.08
# 2  2015   11  21.15
# 3  2009    6  11.54
# Município:  BARRA DE SANTO ANTÔNIO  -  12528 eleitores
#     ANO  QTD      %
# 0  2015   19  54.29
# 1  2010   13  37.14
# 2  2009    2   5.71
# 3  2013    1   2.86
# Município:  PARIPUEIRA  -  11062 eleitores
#     ANO  QTD      %
# 0  2015   21  72.41
# 1  2010    4  13.79
# 2  2009    3  10.34
# 3  2013    1   3.45
# Município:  SÃO LUÍS DO QUITUNDE  -  23464 eleitores
#     ANO  QTD      %
# 0  2015   38  55.07
# 1  2010   24  34.78
# 2  2013    5   7.25
# 3  2009    2   2.90
# Município:  OLIVENÇA  -  9626 eleitores
#     ANO  QTD      %
# 0  2009   13  41.94
# 1  2015   12  38.71
# 2  2010    6  19.35
# Município:  SANTANA DO IPANEMA  -  32037 eleitores
#     ANO  QTD     %
# 0  2015   46  46.0
# 1  2009   44  44.0
# 2  2010    7   7.0
# 3  2013    3   3.0
# Município:  CARNEIROS  -  6957 eleitores
#     ANO  QTD      %
# 0  2015    8  36.36
# 1  2010    6  27.27
# 2  2009    5  22.73
# 3  2013    3  13.64
# Município:  TRAIPU  -  18304 eleitores
#     ANO  QTD      %
# 0  2010   33  52.38
# 1  2009   27  42.86
# 2  2015    3   4.76
# Município:  CAMPO GRANDE  -  8938 eleitores
#     ANO  QTD     %
# 0  2009   15  62.5
# 1  2010    9  37.5
# Município:  SANTANA DO MUNDAÚ  -  8996 eleitores
#     ANO  QTD      %
# 0  2010   14  50.00
# 1  2009    8  28.57
# 2  2015    5  17.86
# 3  2013    1   3.57
# Município:  UNIÃO DOS PALMARES  -  46244 eleitores
#     ANO  QTD      %
# 0  2010   50  36.50
# 1  2015   40  29.20
# 2  2009   29  21.17
# 3  2013   18  13.14
# Município:  CANAPI  -  13628 eleitores
#     ANO  QTD      %
# 0  2009   14  34.15
# 1  2010   12  29.27
# 2  2015   11  26.83
# 3  2013    4   9.76
# Município:  MATA GRANDE  -  17707 eleitores
#     ANO  QTD      %
# 0  2010   22  41.51
# 1  2009   14  26.42
# 2  2015   14  26.42
# 3  2013    3   5.66
# Município:  QUEBRANGULO  -  10028 eleitores
#     ANO  QTD      %
# 0  2010   17  56.67
# 1  2009    6  20.00
# 2  2013    4  13.33
# 3  2015    3  10.00
# Município:  PAULO JACINTO  -  6252 eleitores
#     ANO  QTD      %
# 0  2010   20  95.24
# 1  2009    1   4.76
# Município:  CHÃ PRETA  -  6089 eleitores
#     ANO  QTD      %
# 0  2010   14  77.78
# 1  2009    3  16.67
# 2  2013    1   5.56
# Município:  BELÉM  -  4978 eleitores
#     ANO  QTD      %
# 0  2010    8  38.10
# 1  2013    5  23.81
# 2  2015    5  23.81
# 3  2009    3  14.29
# Município:  BATALHA  -  13059 eleitores
#     ANO  QTD      %
# 0  2009   20  57.14
# 1  2010    7  20.00
# 2  2013    4  11.43
# 3  2015    4  11.43
# Município:  BELO MONTE  -  6025 eleitores
#     ANO  QTD     %
# 0  2010    6  37.5
# 1  2009    4  25.0
# 2  2013    4  25.0
# 3  2015    2  12.5
# Município:  JACARÉ DOS HOMENS  -  4908 eleitores
#     ANO  QTD      %
# 0  2013    4  28.57
# 1  2015    4  28.57
# 2  2009    3  21.43
# 3  2010    3  21.43
# Município:  MONTEIRÓPOLIS  -  5973 eleitores
#     ANO  QTD      %
# 0  2009    9  47.37
# 1  2010    6  31.58
# 2  2015    4  21.05
# Município:  MAJOR ISIDORO  -  15242 eleitores
#     ANO  QTD      %
# 0  2009   13  31.71
# 1  2015   11  26.83
# 2  2010    9  21.95
# 3  2013    8  19.51
# Município:  CRAÍBAS  -  19310 eleitores
#     ANO  QTD      %
# 0  2009   28  53.85
# 1  2010   16  30.77
# 2  2015    7  13.46
# 3  2013    1   1.92
# Município:  TEOTÔNIO VILELA  -  30655 eleitores
#     ANO  QTD      %
# 0  2015   38  45.78
# 1  2010   24  28.92
# 2  2013   15  18.07
# 3  2009    6   7.23
# Município:  JUNQUEIRO  -  19809 eleitores
#     ANO  QTD      %
# 0  2015   35  57.38
# 1  2013   12  19.67
# 2  2009   11  18.03
# 3  2010    3   4.92
# Município:  PORTO REAL DO COLÉGIO  -  16131 eleitores
#     ANO  QTD      %
# 0  2009   22  46.81
# 1  2010   18  38.30
# 2  2013    5  10.64
# 3  2015    2   4.26
# Município:  SÃO BRÁS  -  6674 eleitores
#     ANO  QTD      %
# 0  2009    8  44.44
# 1  2010    7  38.89
# 2  2013    2  11.11
# 3  2015    1   5.56
# Município:  OLHO D'ÁGUA GRANDE  -  4825 eleitores
#     ANO  QTD      %
# 0  2013    5  38.46
# 1  2015    4  30.77
# 2  2009    3  23.08
# 3  2010    1   7.69
# Município:  IGREJA NOVA  -  17551 eleitores
#     ANO  QTD      %
# 0  2015   20  38.46
# 1  2013   17  32.69
# 2  2009    8  15.38
# 3  2010    7  13.46
# Município:  ÁGUA BRANCA  -  15931 eleitores
#     ANO  QTD      %
# 0  2009   22  53.66
# 1  2010   13  31.71
# 2  2013    3   7.32
# 3  2015    3   7.32
# Município:  PARICONHA  -  9064 eleitores
#     ANO  QTD     %
# 0  2009    9  36.0
# 1  2010    9  36.0
# 2  2013    4  16.0
# 3  2015    3  12.0
# Município:  INHAPI  -  13273 eleitores
#     ANO  QTD      %
# 0  2010   22  53.66
# 1  2009   13  31.71
# 2  2015    4   9.76
# 3  2013    2   4.88
# Município:  DELMIRO GOUVEIA  -  39011 eleitores
#     ANO  QTD      %
# 0  2009   63  48.46
# 1  2010   41  31.54
# 2  2015   16  12.31
# 3  2013   10   7.69
# Município:  PIRANHAS  -  18871 eleitores
#     ANO  QTD      %
# 0  2009   22  43.14
# 1  2010   20  39.22
# 2  2015    7  13.73
# 3  2013    2   3.92
# Município:  OLHO D'ÁGUA DO CASADO  -  7445 eleitores
#     ANO  QTD     %
# 0  2010    9  45.0
# 1  2015    8  40.0
# 2  2013    2  10.0
# 3  2009    1   5.0
# Município:  GIRAU DO PONCIANO  -  27383 eleitores
#     ANO  QTD      %
# 0  2009   30  41.67
# 1  2015   18  25.00
# 2  2010   13  18.06
# 3  2013   11  15.28
# Município:  JARAMATAIA  -  4979 eleitores
#     ANO  QTD     %
# 0  2009    8  50.0
# 1  2010    6  37.5
# 2  2013    2  12.5
# Município:  LAGOA DA CANOA  -  15094 eleitores
#     ANO  QTD      %
# 0  2010   19  46.34
# 1  2009   16  39.02
# 2  2013    6  14.63
# Município:  IGACI  -  20099 eleitores
#     ANO  QTD      %
# 0  2015   36  47.37
# 1  2010   17  22.37
# 2  2013   16  21.05
# 3  2009    7   9.21
# Município:  TAQUARANA  -  14156 eleitores
#     ANO  QTD      %
# 0  2015   22  51.16
# 1  2010   14  32.56
# 2  2013    5  11.63
# 3  2009    2   4.65
# Município:  COITÉ DO NÓIA  -  8898 eleitores
#     ANO  QTD      %
# 0  2015   14  53.85
# 1  2009    8  30.77
# 2  2013    3  11.54
# 3  2010    1   3.85
# Município:  CACIMBINHAS  -  8447 eleitores
#     ANO  QTD      %
# 0  2009   10  41.67
# 1  2010    5  20.83
# 2  2013    5  20.83
# 3  2015    4  16.67
# Município:  MINADOR DO NEGRÃO  -  4904 eleitores
#     ANO  QTD      %
# 0  2009    7  38.89
# 1  2010    6  33.33
# 2  2015    5  27.78
# Município:  DOIS RIACHOS  -  9301 eleitores
#     ANO  QTD      %
# 0  2009   14  51.85
# 1  2010    7  25.93
# 2  2015    6  22.22
# Município:  ESTRELA DE ALAGOAS  -  12001 eleitores
#     ANO  QTD      %
# 0  2013   14  34.15
# 1  2009   11  26.83
# 2  2010    9  21.95
# 3  2015    7  17.07
# Município:  CAMPO ALEGRE  -  25818 eleitores
#     ANO  QTD      %
# 0  2015   42  56.00
# 1  2013   16  21.33
# 2  2009   11  14.67
# 3  2010    6   8.00
# Município:  LIMOEIRO DE ANADIA  -  19048 eleitores
#     ANO  QTD      %
# 0  2015   26  44.83
# 1  2013   22  37.93
# 2  2010   10  17.24
# Município:  BOCA DA MATA  -  19576 eleitores
#     ANO  QTD      %
# 0  2010   28  50.91
# 1  2009   27  49.09
# Município:  TANQUE D'ARCA  -  5492 eleitores
#     ANO  QTD      %
# 0  2009   12  66.67
# 1  2010    6  33.33
# Município:  ANADIA  -  12660 eleitores
#     ANO  QTD      %
# 0  2010   25  56.82
# 1  2009   18  40.91
# 2  2013    1   2.27
# Município:  MARIBONDO  -  10331 eleitores
#     ANO  QTD      %
# 0  2010   18  51.43
# 1  2009   15  42.86
# 2  2015    2   5.71
# Município:  SÃO SEBASTIÃO  -  25939 eleitores
#     ANO  QTD      %
# 0  2009   24  33.33
# 1  2013   19  26.39
# 2  2015   15  20.83
# 3  2010   14  19.44
# Município:  FEIRA GRANDE  -  17899 eleitores
#     ANO  QTD      %
# 0  2009   18  38.30
# 1  2010   15  31.91
# 2  2015    8  17.02
# 3  2013    6  12.77
# Município:  MARAVILHA  -  8130 eleitores
#     ANO  QTD      %
# 0  2009   14  53.85
# 1  2010    7  26.92
# 2  2015    5  19.23
# Município:  POÇO DAS TRINCHEIRAS  -  10466 eleitores
#     ANO  QTD      %
# 0  2015   13  41.94
# 1  2009    8  25.81
# 2  2013    6  19.35
# 3  2010    4  12.90
# Município:  OURO BRANCO  -  9231 eleitores
#     ANO  QTD     %
# 0  2009   16  64.0
# 1  2010    6  24.0
# 2  2013    2   8.0
# 3  2015    1   4.0
# Município:  SÃO JOSÉ DA TAPERA  -  21621 eleitores
#     ANO  QTD      %
# 0  2010   25  43.86
# 1  2009   18  31.58
# 2  2013   10  17.54
# 3  2015    4   7.02
# Município:  SENADOR RUI PALMEIRA  -  9296 eleitores
#     ANO  QTD      %
# 0  2009   10  35.71
# 1  2015    9  32.14
# 2  2010    5  17.86
# 3  2013    4  14.29
# Município:  JOAQUIM GOMES  -  14317 eleitores
#     ANO  QTD      %
# 0  2010   25  46.30
# 1  2009   22  40.74
# 2  2015    5   9.26
# 3  2013    2   3.70
# Município:  FLEXEIRAS  -  8674 eleitores
#     ANO  QTD      %
# 0  2009   14  53.85
# 1  2010   11  42.31
# 2  2013    1   3.85
# Município:  NOVO LINO  -  9852 eleitores
#     ANO  QTD      %
# 0  2010   18  62.07
# 1  2009    7  24.14
# 2  2013    4  13.79
# Município:  CAMPESTRE  -  5660 eleitores
#     ANO  QTD      %
# 0  2010    9  52.94
# 1  2009    8  47.06

# %%
# Cidades próximas ao Município de Capela com perfil menos urbanizado para comparação
mun_prox = ['CAPELA', 'CAJUEIRO', 'PINDOBA', 'VIÇOSA','BRANQUINHA', 'CHÃ PRETA', 'MAR VERMELHO']

for i in range(len(mun_prox)):
    df= df_100k[df_100k['NM_MUNICIPIO'] == mun_prox[i]]
    n = df['QT_APTOS'].sum()
    ab = round(100 * df['QT_ABSTENCOES'].sum() / df['QT_APTOS'].sum(), 2)
    pt = round(100 * df['LULA'].sum() / df['QT_COMPARECIMENTO'].sum(), 2)
    pl = round(100 * df['BOLSO'].sum() / df['QT_COMPARECIMENTO'].sum(), 2)
    nu = round(100 * df['NULOS'].sum() / df['QT_COMPARECIMENTO'].sum(), 2)
    print('Município: ', mun_prox[i],' - ', n, 'eleitores' )
    print('Lula:', pt, '% dos votos')
    print('Bolsonaro:', pl, '% dos votos')
    print('Nulos:', nu, '% dos votos')
    print('Abstenções:',ab, '% dos eleitores \n')
# Out:
# Município:  CAPELA  -  12931 eleitores
# Lula: 55.53 % dos votos
# Bolsonaro: 37.42 % dos votos
# Nulos: 7.05 % dos votos
# Abstenções: 27.19 % dos eleitores
#
# Município:  CAJUEIRO  -  14547 eleitores
# Lula: 62.95 % dos votos
# Bolsonaro: 29.35 % dos votos
# Nulos: 7.7 % dos votos
# Abstenções: 29.94 % dos eleitores
#
# Município:  PINDOBA  -  2674 eleitores
# Lula: 62.67 % dos votos
# Bolsonaro: 29.52 % dos votos
# Nulos: 7.8 % dos votos
# Abstenções: 24.76 % dos eleitores
#
# Município:  VIÇOSA  -  20273 eleitores
# Lula: 60.64 % dos votos
# Bolsonaro: 32.56 % dos votos
# Nulos: 6.79 % dos votos
# Abstenções: 24.87 % dos eleitores
#
# Município:  BRANQUINHA  -  9105 eleitores
# Lula: 65.88 % dos votos
# Bolsonaro: 25.61 % dos votos
# Nulos: 8.51 % dos votos
# Abstenções: 32.63 % dos eleitores
#
# Município:  CHÃ PRETA  -  6089 eleitores
# Lula: 71.14 % dos votos
# Bolsonaro: 21.92 % dos votos
# Nulos: 6.94 % dos votos
# Abstenções: 27.84 % dos eleitores
#
# Município:  MAR VERMELHO  -  3536 eleitores
# Lula: 67.18 % dos votos
# Bolsonaro: 27.0 % dos votos
# Nulos: 5.82 % dos votos
# Abstenções: 21.24 % dos eleitores

# %%
lista = []

for i in range(len(br_mun_uf)):
    if br_mun_uf['name_muni'][i] == 'CAPELA':
        x = 2
    else:
        if br_mun_uf['name_muni'][i] in mun_prox:
            x = 1
        else:
            x = 0
            
    lista.append(x)
    
br_mun_uf['mod_2020'] = lista


# Plotando o Mapa
data = br_mun_uf[['geometry', 'mod_2020']]

f, ax = plt.subplots()
f.set_size_inches(16, 16)
data.plot(ax=ax, # Axis de destino do gráfico
          column= 'mod_2020', # Coluna com os valores usados para colorir o mapa
          cmap='Oranges', # Mapa de cores
          edgecolor='black', # Cor dos contornos
          linewidth=0.25) # Espessura dos contornos
# Out:
# <AxesSubplot:>
